# %% [markdown]
# # Graph Networks & Visualization
# ## Overview
# Implementation and visualization of graph networks using NetworkX. Explores relationships and connections between nodes representing real-world entities.
# ## Key Concepts
#
# Graph theory fundamentals
# Node and edge relationships
# Graph visualization using NetworkX and Matplotlib
#
# ## Libraries Used
#
# NetworkX, Matplotlib

# %%
import networkx as nx
import matplotlib.pyplot as plt

edges = [
    ("Aarav", "Ayaan", "Friend"),
    ("Aarav", "Diya", "Friend"),
    ("Ayaan", "Karan", "Colleague"),
    ("Diya", "Karan", "Colleague"),
    ("Karan", "Meera", "Family"),
    ("Meera", "Aarav", "Family"),
    ("Diya", "Aarav", "Friend"),
    ("Ayaan", "Aarav", "Friend"),
    ("Karan", "Diya", "Colleague"),
    ("Aarav", "Meera", "Family")
]

# Create a graph object
G = nx.Graph()

# Add nodes and edges to the graph
for source, target, relationship in edges:
    G.add_edge(source, target, label=relationship)

# Define the positions of nodes in the graph
pos = nx.spring_layout(G)

# Draw the graph with labels
plt.figure(figsize=(8, 6))
nx.draw(G, pos, with_labels=True, node_size=3000, node_color="skyblue", font_size=12, font_weight="bold", edge_color="gray")
labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

# Show the plot
plt.title("Social Network Relationship Graph")
plt.show()
